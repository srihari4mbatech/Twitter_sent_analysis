# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
# %matplotlib notebook
pd.set_option('display.width',1000)

# %%
twit_train_data= pd.read_csv("train.csv")
twit_test_data=pd.read_csv("test.csv")

# %%
twit_train_data.info()
twit_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
# id       31962 non-null int64
# label    31962 non-null int64
# tweet    31962 non-null object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17197 entries, 0 to 17196
# Data columns (total 2 columns):
# id       17197 non-null int64
# tweet    17197 non-null object
# dtypes: int64(1), object(1)
# memory usage: 268.8+ KB

# %% [markdown]
# Train data has 31962 rows of information, target variable is label, and input data is tweets of people.
# Test data has 17197 rows of informaion, with 17000_ tweets

# %%
def con(x):
    if isinstance(x,int):
        return str(x)
    return x
print(type(con(123)))

lst= [1,23,45,69]
lst1=lst.reverse()
lst1=''.join(map(str,lst))
print(type(lst1))
# Out:
# <class 'str'>
# <class 'str'>

# %%
twit_train_data['len']=twit_train_data['tweet'].apply(lambda x: len(x))

# %%
twit_train_data['clean_d']= twit_train_data['tweet'].apply(lambda x:' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x).split()))

# %%
twit_train_data['len']=twit_train_data['clean_d'].apply(lambda x: len(x))
twit_train_data['len'].describe()
# Out:
# count    31962.000000
# mean        70.469526
# std         28.261746
# min          0.000000
# 25%         48.000000
# 50%         72.000000
# 75%         92.000000
# max        139.000000
# Name: len, dtype: float64

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
twit_train_data['len'].hist(bins=20,ax=ax)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
word_freq=pd.DataFrame(data=twit_train_data['clean_d'].str.split(expand=True).stack().value_counts())

# %%
if len(word_freq.columns) ==1:
    word_freq.reset_index(inplace=True)
word_freq.head(10)
# Out:
#   words  count
# 0   the  10229
# 1    to   9863
# 2     i   7622
# 3     a   6527
# 4   you   5952
# 5   and   4947
# 6    in   4675
# 7   for   4510
# 8    of   4256
# 9    is   4197

# %%
word_freq.columns=['words','count']

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
word_freq['count'].hist(bins=5,ax=ax)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
